# %%
import pandas as pd

# %%
info = pd.read_csv('E:\Стажировки\B1 - подготовка к собеседованию\Eurostat_Table_HICPv2.csv')

pd.set_option("display.max_rows", 6)  # display only six entries

# %%
info.head()  # display five first DataFrame's entries
# Out:
#                                      geo  2008  2009  2010  2011  2012  2013  \
# 0  European Union (changing composition)   3.7   1.0   2.1   3.1   2.6   1.5
# 1          EU (27 countries - from 2020)   3.7   0.8   1.8   2.9   2.6   1.3
# 2                      EU (28 countries)   3.7   1.0   2.1   3.1   2.6   1.5
# 3       Euro area (changing composition)   3.3   0.3   1.6   2.7   2.5   1.4
# 4  Euro area - 19 countries  (from 2015)   3.3   0.3   1.6   2.7   2.5   1.3
#
#    2014  2015  2016  2017  2018  2019
# 0   0.6   0.1   0.2   1.7   1.9   1.5
# 1   0.4   0.1   0.2   1.6   1.8   1.4
# 2   0.6   0.1   0.2   1.7   1.9   1.5
# 3   0.4   0.2   0.2   1.5   1.8   1.2
# 4   0.4   0.2   0.2   1.5   1.8   1.2

# %%
info.geo
# Out:
# 0     European Union (changing composition)
# 1             EU (27 countries - from 2020)
# 2                         EU (28 countries)
#                       ...
# 38                                   Serbia
# 39                                   Turkey
# 40                            United States
# Name: geo, Length: 41, dtype: object

# %%
info['2010']  # to get data from digital column number
# Out:
# 0     2.1
# 1     1.8
# 2     2.1
#      ...
# 38    6.2
# 39    8.6
# 40    2.6
# Name: 2010, Length: 41, dtype: float64

# %%
info['geo'][15]  # access to the 16th row label
# Out:
# 'France'

# %%
info.iloc[15]
# Out:
# geo     France
# 2008       3.2
# 2009       0.1
#          ...
# 2017       1.2
# 2018       2.1
# 2019       1.3
# Name: 15, Length: 13, dtype: object

# %%
info.iloc[:, 0]
# Out:
# 0     European Union (changing composition)
# 1             EU (27 countries - from 2020)
# 2                         EU (28 countries)
#                       ...
# 38                                   Serbia
# 39                                   Turkey
# 40                            United States
# Name: geo, Length: 41, dtype: object

# %%
info.iloc[:3, 0]
# Out:
# 0    European Union (changing composition)
# 1            EU (27 countries - from 2020)
# 2                        EU (28 countries)
# Name: geo, dtype: object

# %%
info.iloc[[1, 3, 5], [0, 2]]
# Out:
#                                 geo  2009
# 1     EU (27 countries - from 2020)   0.8
# 3  Euro area (changing composition)   0.3
# 5   Euro area - 18 countries (2014)   0.3

# %%
df = info[:]

# %%
df.loc[[14, 23], ['geo', '2009', '2013']]
# Out:
#       geo  2009  2013
# 14  Spain  -0.2   1.5
# 23  Malta   1.8   1.0

# %%
# df.set_index('geo')  -> run it without #

# %%
df.loc[:, ['2008', '2009']] <= 5
# shows countries with inflation level below 5%
# Out:
#      2008   2009
# 0    True   True
# 1    True   True
# 2    True   True
# ..    ...    ...
# 38  False  False
# 39  False  False
# 40   True   True
#
# [41 rows x 2 columns]

# %%
df.loc[df['geo'] == 'Turkey', ['2008', '2009']] <= 10
# Out:
#      2008  2009
# 39  False  True

# %%
df.loc[df['geo'] == 'United States']
# Out:
#               geo  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# 40  United States   4.4  -0.8   2.6   3.9   2.2   1.3   1.3  -0.8   0.5   1.7
#
#     2018  2019
# 40   2.2   1.3

# %%
df.loc[df.geo.isin(['Serbia', 'United States'])]
# Out:
#               geo  2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# 38         Serbia  11.9   8.2   6.2  11.2   7.4   7.7   2.3   1.5   1.3   3.3
# 40  United States   4.4  -0.8   2.6   3.9   2.2   1.3   1.3  -0.8   0.5   1.7
#
#     2018  2019
# 38   2.0   1.9
# 40   2.2   1.3

# %%
df.iloc[:, 1:]
# Out:
#     2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 0    3.7   1.0   2.1   3.1   2.6   1.5   0.6   0.1   0.2   1.7   1.9   1.5
# 1    3.7   0.8   1.8   2.9   2.6   1.3   0.4   0.1   0.2   1.6   1.8   1.4
# 2    3.7   1.0   2.1   3.1   2.6   1.5   0.6   0.1   0.2   1.7   1.9   1.5
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 38  11.9   8.2   6.2  11.2   7.4   7.7   2.3   1.5   1.3   3.3   2.0   1.9
# 39  10.4   6.3   8.6   6.5   9.0   7.5   8.9   7.7   7.7  11.1  16.3  15.2
# 40   4.4  -0.8   2.6   3.9   2.2   1.3   1.3  -0.8   0.5   1.7   2.2   1.3
#
# [41 rows x 12 columns]

# %% [markdown]
# # Exercise 2

# %%
import pandas as pd

# %%
reviews = pd.read_csv("E:\Стажировки\B1 - подготовка к собеседованию\winemag-data-130k-v2.csv",
                     index_col=0)
reviews
# Out:
#         country                                        description  \
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# 2            US  Tart and snappy, the flavors of lime flesh and...
# ...         ...                                                ...
# 65496        US  Much improved over the unripe 2005, Fritz's 20...
# 65497        US  This wine wears its 15.8% alcohol better than ...
# 65498     Spain  A unique take on Manzanilla Sherry, which is o...
#
#         designation  points  price           province           region_1  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1          Avidagos      87   15.0              Douro                NaN
# 2               NaN      87   14.0             Oregon  Willamette Valley
# ...             ...     ...    ...                ...                ...
# ...

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
desc = reviews.description
type(desc)
# Out:
# pandas.core.series.Series

# %%
desc

# %%
first_description = reviews["description"][0]
first_description
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
first_row = reviews.iloc[0]
first_row
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
# designation                                         Vulkà Bianco
#                                      ...
# title                          Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
first_descriptions = reviews["description"].iloc[:10]
first_descriptions
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
#                            ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
desc.head(10)
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
#                            ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
reviews.loc[:9, "description"]
# Out:
# 0    Aromas include tropical fruit, broom, brimston...
# 1    This is ripe and fruity, a wine that is smooth...
# 2    Tart and snappy, the flavors of lime flesh and...
#                            ...
# 7    This dry and restrained wine offers spice in p...
# 8    Savory dried thyme notes accent sunnier flavor...
# 9    This has great depth of flavor with its fresh ...
# Name: description, Length: 10, dtype: object

# %%
sample_reviews = reviews.iloc[[1, 2, 3, 5, 8], :]
sample_reviews
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %%
df = reviews.loc[[0, 1, 10, 100],
                 ['country', 'province', 'region_1', 'region_2']]
df
# Out:
#       country           province      region_1      region_2
# 0       Italy  Sicily & Sardinia          Etna           NaN
# 1    Portugal              Douro           NaN           NaN
# 10         US         California   Napa Valley          Napa
# 100        US           New York  Finger Lakes  Finger Lakes

# %%
df = reviews.loc[:99, ['country', 'variety']]
df
# Out:
#      country                   variety
# 0      Italy               White Blend
# 1   Portugal            Portuguese Red
# 2         US                Pinot Gris
# ..       ...                       ...
# 97        US                  Riesling
# 98     Italy                Sangiovese
# 99        US  Bordeaux-style Red Blend
#
# [100 rows x 2 columns]

# %%
italian_wines = reviews.loc[reviews['country'] == 'Italy', :]
italian_wines
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 6       Italy  Here's a bright, informal red that opens with ...
# 13      Italy  This is dominated by oak and oak-driven aromas...
# ...       ...                                                ...
# 65476   Italy  Rose, violet, sour berry and tilled earth arom...
# 65477   Italy  Made of 65% Merlot, 25% Cabernet Sauvignon, 5%...
# 65478   Italy  Aromas suggesting French oak, coconut and spic...
#
#         designation  points  price           province  \
# 0      Vulkà Bianco      87    NaN  Sicily & Sardinia
# 6           Belsito      87   16.0  Sicily & Sardinia
# 13            Rosso      87    NaN  Sicily & Sardinia
# ...             ...     ...    ...                ...
# 65476      Prugnolo      88   25.0            Tuscany
# 65477     Ruit Hora      88   30.0            Tuscany
# 65478           NaN      88   36.0            Tuscany
#
# ...

# %%
top_oceania_wines = reviews.loc[
    reviews['country'].isin(['Australia', 'New Zealand']) & 
    (reviews.points >= 95)]

top_oceania_wines
# Out:
#          country                                        description  \
# 345    Australia  This wine contains some material over 100 year...
# 346    Australia  This deep brown wine smells like a damp, mossy...
# 348    Australia  Deep mahogany. Dried fig and black tea on the ...
# ...          ...                                                ...
# 56959  Australia  Is this the Yin to Grange's Yang? The wines ar...
# 59977  Australia  This is a top example of the classic Australia...
# 59984  Australia  This is a throwback to those brash, flavor-exu...
#
#          designation  points  price         province         region_1  \
# 345             Rare     100  350.0         Victoria       Rutherglen
# 346             Rare      98  350.0         Victoria       Rutherglen
# 348            Grand      97  100.0         Victoria       Rutherglen
# ...              ...     ...    ...              ...              ...
# 56959  Hill of Grace      96  820.0  South Australia      Eden Valley
# ...
