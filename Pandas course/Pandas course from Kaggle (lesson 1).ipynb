# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'],
              'Sue': ['Pretty good.', 'Bland.']},
            index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
EU_inflation_rate = pd.read_csv("E:\Стажировки\B1 - подготовка к собеседованию\Eurostat_Table_HICPv2.csv")

# %%
EU_inflation_rate  # between 2008 and 2019 years
# Out:
#                                       geo  2008  2009  2010  2011  2012  2013  \
# 0   European Union (changing composition)   3.7   1.0   2.1   3.1   2.6   1.5
# 1           EU (27 countries - from 2020)   3.7   0.8   1.8   2.9   2.6   1.3
# 2                       EU (28 countries)   3.7   1.0   2.1   3.1   2.6   1.5
# 3        Euro area (changing composition)   3.3   0.3   1.6   2.7   2.5   1.4
# 4   Euro area - 19 countries  (from 2015)   3.3   0.3   1.6   2.7   2.5   1.3
# 5         Euro area - 18 countries (2014)   3.3   0.3   1.6   2.7   2.5   1.4
# 6                                 Belgium   4.5   0.0   2.3   3.4   2.6   1.2
# 7                                Bulgaria  12.0   2.5   3.0   3.4   2.4   0.4
# 8                                 Czechia   6.3   0.6   1.2   2.2   3.5   1.4
# 9                                 Denmark   3.6   1.0   2.2   2.7   2.4   0.5
# 10                                Germany   2.8   0.2   1.1   2.5   2.2   1.6
# ...

# %%
EU_inflation_rate.shape  # 41 record with 13 different columns
# Out:
# (41, 13)

# %%
EU_inflation_rate.head()  # 5 first rows
# Out:
#                                      geo  2008  2009  2010  2011  2012  2013  \
# 0  European Union (changing composition)   3.7   1.0   2.1   3.1   2.6   1.5
# 1          EU (27 countries - from 2020)   3.7   0.8   1.8   2.9   2.6   1.3
# 2                      EU (28 countries)   3.7   1.0   2.1   3.1   2.6   1.5
# 3       Euro area (changing composition)   3.3   0.3   1.6   2.7   2.5   1.4
# 4  Euro area - 19 countries  (from 2015)   3.3   0.3   1.6   2.7   2.5   1.3
#
#    2014  2015  2016  2017  2018  2019
# 0   0.6   0.1   0.2   1.7   1.9   1.5
# 1   0.4   0.1   0.2   1.6   1.8   1.4
# 2   0.6   0.1   0.2   1.7   1.9   1.5
# 3   0.4   0.2   0.2   1.5   1.8   1.2
# 4   0.4   0.2   0.2   1.5   1.8   1.2

# %%
fruits = pd.DataFrame({'Apples': [30], 'Bananas': [21]})
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
fruit_sales = pd.DataFrame({'Apples': [35, 41], 'Bananas': [21, 34]},
                           index=['2017 Sales', '2018 Sales'])
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
ingredients = pd.Series(['4 cups', '1 cup', '2 large', '1 can'],
                       index=['Flour', 'Milk', 'Eggs', 'Spam'],
                       name='Dinner')
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
# reviews = pd.read_csv('../input/wine-reviews/winemag-data_first150k.csv',
#                      index_col=0)
# reviews

# %%
animals = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
animals
# Out:
#         Cows  Goats
# Year 1    12     22
# Year 2    20     19

# %%
df = pd.DataFrame(animals)
df.to_csv('cows_and_goats.csv', encoding='UTF-8')
# animals.to_csv('cows_and_goats.csv')
